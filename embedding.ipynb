# %%
import tensorflow as tf
import pandas as pd
import nltk
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical

# %%
url = 'https://storage.googleapis.com/bucketsformodel/embedding.csv'
data = pd.read_csv(url)

# %%
TRAINING_SIZE = 20000
VOCAB_SIZE = 50000
MAX_LENGTH = 128
EMBEDDING_DIM = 16

# %%
# nltk.download('stopwords')
# nltk.download('punkt')

# %%
# from nltk.corpus import stopwords
# import nltk

# # Pastikan resource NLTK terunduh
# nltk.download('punkt')  # Tokenizer
# nltk.download('stopwords')  # Stopwords
# nltk.download('punkt_tab')

# def preprocess_text(text):
#     """Membersihkan teks: huruf kecil, hapus stopwords."""
#     text = text.lower()
#     words = nltk.word_tokenize(text)  # Tokenizer dari 'punkt'
#     stop_words = set(stopwords.words('indonesian'))  # Stopwords bahasa Indonesia
#     words = [word for word in words if word not in stop_words]  # Hapus stopwords
#     return " ".join(words)

# # Terapkan preprocessing pada kolom 'Deskripsi'
# data['Deskripsi'] = data['Deskripsi'].astype(str).apply(preprocess_text)

# %%
rare_categories = data['Kategori'].value_counts()[data['Kategori'].value_counts() <= 2].index.tolist()
common_data = data[~data['Kategori'].isin(rare_categories)]
rare_data = data[data['Kategori'].isin(rare_categories)]

# %%
# Memisahkan kategori langka (rare) dan umum
rare_categories = data['Kategori'].value_counts()[data['Kategori'].value_counts() <= 2].index.tolist()

# Data dengan kategori umum
common_data = data[~data['Kategori'].isin(rare_categories)]

# Data dengan kategori langka
rare_data = data[data['Kategori'].isin(rare_categories)]

# Stratified split untuk data dengan kategori umum
train_common, test_common = train_test_split(
    common_data,
    test_size=0.2,
    stratify=common_data['Kategori'],
    random_state=42
)

# Gabungkan data kategori langka ke train (agar tetap ada dalam model)
train_data = pd.concat([train_common, rare_data], ignore_index=True)

# Test data tetap hanya dari kategori umum
test_data = test_common

# Hasil
print("Jumlah data Train:", len(train_data))
print("Jumlah data Test:", len(test_data))
print("\nDistribusi data Train:")
print(train_data['Kategori'].value_counts())
print("\nDistribusi data Test:")
print(test_data['Kategori'].value_counts())
# Out:
# Jumlah data Train: 53
# Jumlah data Test: 13
#
# Distribusi data Train:
# Kategori
# Nature & Adventure & Park    27
# Historical & Museum          14
# Waterpark                     6
# Food                          5
# Zoo                           1
# Name: count, dtype: int64
#
# Distribusi data Test:
# Kategori
# Nature & Adventure & Park    7
# Historical & Museum          3
# Food                         2
# Waterpark                    1
# Name: count, dtype: int64

# %%
encoder = OneHotEncoder()
train_labels = encoder.fit_transform(train_data[['Kategori']]).toarray()
test_labels = encoder.transform(test_data[['Kategori']]).toarray()

# %%
tokenizer = Tokenizer(num_words=VOCAB_SIZE)
tokenizer.fit_on_texts(train_data['Deskripsi'])

# %%
train_sequences = tokenizer.texts_to_sequences(train_data['Deskripsi'])
test_sequences = tokenizer.texts_to_sequences(test_data['Deskripsi'])

# Padding sequence
train_padded = pad_sequences(train_sequences, maxlen=MAX_LENGTH, padding='post')
test_padded = pad_sequences(test_sequences, maxlen=MAX_LENGTH, padding='post')

# %%
train_dataset_tf = tf.data.Dataset.from_tensor_slices((train_padded, train_labels))
test_dataset_tf = tf.data.Dataset.from_tensor_slices((test_padded, test_labels))

# %%
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

train
 55, 18, 2, 228, 69, 3, 98, 97], [259, 11, 21, 10, 3, 59, 1, 13, 28, 875, 124, 334, 3, 77, 357, 876, 27, 459, 2, 137, 17, 103, 104, 315, 7, 4, 790, 154, 292, 6, 630, 22, 155, 65, 64, 38, 33, 12, 30, 8, 63, 14, 55, 18, 666, 22, 114, 135, 124, 1, 230, 5, 28, 10, 48, 229, 14, 7, 491, 2, 145, 80, 576, 810, 16, 21, 3, 259], [13, 16, 21, 141, 3, 77, 779, 1, 57, 2, 147, 3, 59, 34, 30, 577, 352, 481, 212, 6, 437, 246, 212, 19, 543, 288, 20, 52, 88, 60, 574, 21, 79, 220, 2, 98, 55, 1, 61, 6, 38, 27, 459, 1, 137, 17, 103, 104, 315, 7, 4, 7, 4, 12, 520, 39, 630, 48, 69, 2, 808, 519, 519, 1, 782, 122, 4, 61, 6, 21, 141, 15, 221, 38, 1, 24, 8, 206, 187, 31, 84, 71, 840, 212], [58, 3, 42, 58, 11, 39, 55, 1, 61, 6, 44, 44, 2, 38, 1, 24, 414, 5, 3, 98, 4, 33, 30, 417, 80, 2, 55, 5, 1, 416, 2, 985, 7, 4, 937, 5, 27, 1, 149, 2, 121, 506, 431, 5, 48, 141, 71, 418, 419, 420, 58, 17, 285, 43, 6, 108, 206, 64, 38]]

# %%
# Vectorize Text Data
vectorize_layer = layers.TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_sequence_length=MAX_LENGTH
)

# %%
# Fit vectorizer on training data
vectorize_layer.adapt(train_data['Deskripsi'])

# %%
# Vectorize text data
X_train_vectorized = vectorize_layer(train_data['Deskripsi'])
X_test_vectorized = vectorize_layer(test_data['Deskripsi'])

# %%
# Encode the labels to integers
label_encoder = {label: idx for idx, label in enumerate(data['Kategori'].unique())}
train_data['Kategori_encoded'] = train_data['Kategori'].map(label_encoder)
test_data['Kategori_encoded'] = test_data['Kategori'].map(label_encoder)

# %%
# Convert labels to one-hot encoding
num_classes = len(label_encoder)
y_train_onehot = to_categorical(train_data['Kategori_encoded'], num_classes)
y_test_onehot = to_categorical(test_data['Kategori_encoded'], num_classes)

# %%
# Define the Model
model = models.Sequential([
    layers.Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_DIM, input_length=MAX_LENGTH),
    layers.GlobalAveragePooling1D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Compile the Model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the Model
history = model.fit(
    X_train_vectorized, y_train_onehot,
    validation_data=(X_test_vectorized, y_test_onehot),
    epochs=100,
    batch_size=32
)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.4456 - loss: 1.6027 - val_accuracy: 0.5385 - val_loss: 1.5870
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5250 - loss: 1.5845 - val_accuracy: 0.5385 - val_loss: 1.5628
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5271 - loss: 1.5578 - val_accuracy: 0.5385 - val_loss: 1.5316
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4729 - loss: 1.5313 - val_accuracy: 0.5385 - val_loss: 1.4926
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5167 - loss: 1.4910 - val_accuracy: 0.5385 - val_loss: 1.4446
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5375 - loss: 1.4476 - val_accuracy: 0.5385 - val_loss: 1.3904
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4855 - loss: 1.3841 - val_accuracy: 0.5385 - val_loss: 1.3319
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5167 - loss: 1.3010 - val_accuracy: 0.5385 - val_loss: 1.2722
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5271 - loss: 1.2868 - val_accuracy: 0.5385 - val_loss: 1.2241
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5063 - loss: 1.3044 - val_accuracy: 0.5385 - val_loss: 1.1953
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5167 - loss: 1.2397 - val_accuracy: 0.5385 - val_loss: 1.1793
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9059 - loss: 0.2303 - val_accuracy: 0.7692 - val_loss: 0.4075
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9163 - loss: 0.2352 - val_accuracy: 0.8462 - val_loss: 0.3975
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9141 - loss: 0.1935 - val_accuracy: 0.9231 - val_loss: 0.3874
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9289 - loss: 0.2248 - val_accuracy: 0.9231 - val_loss: 0.3774
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9310 - loss: 0.2371 - val_accuracy: 0.9231 - val_loss: 0.3697
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8724 - loss: 0.2474 - val_accuracy: 0.9231 - val_loss: 0.3655
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9414 - loss: 0.2167 - val_accuracy: 0.9231 - val_loss: 0.3639
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9393 - loss: 0.1874 - val_accuracy: 0.8462 - val_loss: 0.3630
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8807 - loss: 0.1874 - val_accuracy: 0.8462 - val_loss: 0.3633
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9080 - loss: 0.2212 - val_accuracy: 0.8462 - val_loss: 0.3637

# %%
# Evaluasi Model
loss, accuracy = model.evaluate(X_test_vectorized, y_test_onehot)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8462 - loss: 0.3637
# Test Loss: 0.3637
# Test Accuracy: 0.8462

# %%
import matplotlib.pyplot as plt

# Plot Training and Validation Accuracy
plt.figure(figsize=(12, 6))

# Akurasi
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# Prediksi Probabilitas
predictions_prob = model.predict(X_test_vectorized)

# Prediksi Label (kategori dengan probabilitas tertinggi)
predictions = predictions_prob.argmax(axis=1)

# Map kembali label angka ke nama kategori
decoded_predictions = [list(label_encoder.keys())[list(label_encoder.values()).index(pred)] for pred in predictions]

# Contoh 5 prediksi pertama
for i in range(5):
    print(f"Teks: {test_data['Deskripsi'].iloc[i]}")  # Ambil dari test_data['Deskripsi']
    print(f"Kategori Prediksi: {decoded_predictions[i]}")
    print(f"Kategori Sebenarnya: {list(label_encoder.keys())[list(label_encoder.values()).index(test_data['Kategori_encoded'].iloc[i])]}")
    print()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bb0cb8d9b40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Teks: Ingin melarikan diri sejenak dari hiruk pikuk kota? Taman Hutan Rakyat adalah jawabannya! Dengan udara segar dan pemandangan alam yang hijau sejauh mata memandang, Tahura menawarkan pengalaman mendalam dengan alam. Nikmati sensasi trekking di tengah hutan pinus yang rindang, berkemah di bawah langit penuh bintang, atau sekadar bersantai di tepi sungai sambil menikmati suara gemericik air. Bagi pecinta petualangan, Tahura adalah surga tersembunyi yang wajib dikunjungi.
# Kategori Prediksi: Nature & Adventure & Park
# Kategori Sebenarnya: Nature & Adventure & Park
#
# Teks: Pernahkah Anda membayangkan bisa mendengar suara asli para legenda musik Indonesia? Di Lokananta, studio rekaman pertama dan terbesar di tanah air, mimpi itu bisa jadi kenyataan! Dengan koleksi ribuan piringan hitam dan master rekaman asli, Lokananta adalah kapsul waktu yang menyimpan sejarah musik Indonesia. Selain menjadi surga bagi para pencinta musik, Lokananta juga menawarkan pengalaman unik yang tak akan Anda temukan di tempat lain. Kunjungi museum mini yang menyimpan berbagai memorabilia musik, ikuti workshop rekaman, atau nikmati pertunjukan musik live dari musisi-musisi berbakat. Lokananta adalah destinasi wisata yang cocok untuk semua kalangan, baik Anda penggemar musik veteran maupun generasi muda yang ingin mengenal lebih dekat sejarah musik Indonesia. Jangan lewatkan kesempatan untuk mengunjungi tempat legendaris ini!
# Kategori Prediksi: Historical & Museum
# Kategori Sebenarnya: Historical & Museum
#
# Teks: Candi Kethek, yang terletak tidak jauh dari Candi Cetho, adalah situs purbakala lain di kawasan Gunung Lawu. Candi ini memiliki bentuk unik menyerupai piramida bertingkat yang mencerminkan budaya Hindu-Jawa. Meski tidak sebesar Candi Cetho, keasrian dan kesederhanaan Candi Kethek memiliki daya tarik tersendiri.
#
# Lokasi candi ini cukup tersembunyi di dalam hutan, sehingga pengunjung dapat menikmati suasana yang tenang dan alami selama perjalanan. Candi ini sering dikunjungi sebagai bagian dari eksplorasi sejarah dan budaya di kawasan lereng Gunung Lawu.
# Kategori Prediksi: Historical & Museum
# Kategori Sebenarnya: Historical & Museum
#
# Teks: Air Terjun Jumog, yang dikenal sebagai surga yang hilang, adalah destinasi alam di Tawangmangu, Karanganyar. Dikelilingi oleh pepohonan yang rindang dan udara sejuk pegunungan, air terjun ini memberikan suasana yang menenangkan. Jalur menuju air terjun dapat ditempuh dengan mudah, meski membutuhkan sedikit berjalan kaki, sehingga cocok untuk semua kalangan.
#
# Fasilitas seperti jembatan kayu, warung makan, dan area bermain anak mempermudah kunjungan wisatawan. Dengan ketinggian sekitar 30 meter, Air Terjun Jumog menjadi pilihan ideal untuk melepas penat dan menikmati keindahan alam yang memikat.
# Kategori Prediksi: Nature & Adventure & Park
# Kategori Sebenarnya: Nature & Adventure & Park
#
# Teks: Rasakan kelezatan serabi legendaris Solo yang telah melegenda sejak zaman dahulu! Serabi Notosuman, dengan resep turun-temurun, menawarkan cita rasa yang khas dan sulit ditemukan di tempat lain. Tekstur lembut, manis yang pas, dan aroma pandan yang semerbak akan memanjakan lidah Anda. Setiap gigitan serabi ini adalah perjalanan waktu menuju masa lalu, membawa Anda merasakan kenikmatan kuliner yang autentik. Kunjungi Serabi Notosuman dan cicipi sendiri mengapa kudapan ini begitu dicintai oleh banyak orang.
# Kategori Prediksi: Historical & Museum
# Kategori Sebenarnya: Food

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Konversi label sebenarnya dari one-hot encoding ke bentuk asli
y_test_actual = test_data['Kategori_encoded'].values  # Ambil dari test_data

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_actual, predictions)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.keys(), yticklabels=label_encoder.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# Ambil hanya kategori yang muncul dalam data uji
present_labels = sorted(set(y_test_actual))  # Label yang ada di y_test_actual
present_target_names = [list(label_encoder.keys())[list(label_encoder.values()).index(label)] for label in present_labels]

# Classification Report
report = classification_report(y_test_actual, predictions, labels=present_labels, target_names=present_target_names)
print(report)
# Out:
#                            precision    recall  f1-score   support
#
# Nature & Adventure & Park       0.88      1.00      0.93         7
#       Historical & Museum       0.75      1.00      0.86         3
#                      Food       1.00      0.50      0.67         2
#                 Waterpark       0.00      0.00      0.00         1
#
#                  accuracy                           0.85        13
#                 macro avg       0.66      0.62      0.61        13
#              weighted avg       0.80      0.85      0.80        13
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# # Data Baru
# new_texts = ["kuliner khas Solo"]
# new_texts_vectorized = vectorize_layer(new_texts)

# # Prediksi
# new_predictions_prob = model.predict(new_texts_vectorized)
# new_predictions = new_predictions_prob.argmax(axis=1)
# new_decoded_predictions = [list(label_encoder.keys())[list(label_encoder.values()).index(pred)] for pred in new_predictions]

# print(f"Prediksi untuk teks baru: {new_decoded_predictions}")

# %%
# Simpan model
model.save("text_classification_modelnew.h5")

# Muat model
loaded_model = tf.keras.models.load_model("text_classification_model.h5")

# Gunakan untuk prediksi
loaded_predictions = loaded_model.predict(new_texts_vectorized)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bb0cd8089d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
